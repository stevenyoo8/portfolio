# %% [markdown]
# #### MongoDB Code Lab

# %%
CONNECT="/usr/bin/mongosh $HOST -u $USER -p $PW --quiet"

# %%
# !{CONNECT}
# Out:
#  Atlas atlas-mya2be-shard-0 [primary] sample_restaurants>
# (To exit, press Ctrl+C again or Ctrl+D or type .exit)
# Atlas atlas-mya2be-shard-0 [primary] sample_restaurants>

# %%
# !{CONNECT} --eval "show collections"
# Out:
#  neighborhoods
# restaurants

# %%
# !{CONNECT} --eval "db.restaurants.findOne()"

# %%
# !{CONNECT} -f /home/jupyter/snippets/mongo_queries.js

# %% [markdown]
# #### Prompt 1: Find the restaurants whose borough = Manhattan, whose cuisine = Pizza, and whose name is NOT Domino'S Pizza. Return their borough, cuisine, and name. Sort the resulting documents by name. Limit the number of results to 5.

# %%
# !{CONNECT} -f /home/jupyter/snippets/mongo_queries.js

# %% [markdown]
# #### Prompt 2: Find the number of restaurants whose borough = Manhattan, whose cuisine = Pizza, and whose name is NOT Domino'S Pizza.

# %%
# !{CONNECT} -f /home/jupyter/snippets/mongo_queries.js

# %% [markdown]
# # BEGIN PROJECT 6 WORK

# %%
# %env HOST=mongodb+srv://cluster0.8hbbecy.mongodb.net/sample_weatherdata
# %env USER=stevenyoo100
# %env PW=oGZncL7DSMKDAATB
# Out:
# env: HOST=mongodb+srv://cluster0.8hbbecy.mongodb.net/sample_weatherdata
# env: USER=stevenyoo100
# env: PW=oGZncL7DSMKDAATB

# %%
CONNECT="/usr/bin/mongosh $HOST -u $USER -p $PW --quiet"

# %%
# !{CONNECT} --eval "show collections"
# Out:
#  data

# %%
# !{CONNECT} -f /home/jupyter/snippets/project6_queries.js
# Out:
#  ****************************************************************
# 1) Locations with temperature between 10 and 20 degrees Celcius
# [
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -5,
#         37.1
#       ]
#     },
#     airTemperature: {
#       value: 10.1,
#       quality: '1'
#     },
#     pressure: {
#       value: 1014,
#       quality: '1'
#     },
#     wind: {
#       direction: {
#         angle: 350,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 18,
#         quality: '1'
#       }
#     }
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -30.5,
#         41.8
#       ]
#     },
#     airTemperature: {
#       value: 10.1,
#       quality: '1'
#     },
#     pressure: {
#       value: 9999.9,
#       quality: '9'
#     },
#     wind: {
#       direction: {
#         angle: 110,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 7.2,
#         quality: '1'
#       }
#     }
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -0.4,
#         36
#       ]
#     },
#     airTemperature: {
#       value: 10.1,
#       quality: '1'
#     },
#     pressure: {
#       value: 1019.6,
#       quality: '1'
#     },
#     wind: {
#       direction: {
#         angle: 90,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 6.2,
#         quality: '1'
#       }
#     }
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -16.3,
#         52.4
#       ]
#     },
#     airTemperature: {
#       value: 10.1,
#       quality: '1'
#     },
#     pressure: {
#       value: 1039.9,
#       quality: '1'
#     },
#     wind: {
#       direction: {
#         angle: 160,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 8,
#         quality: '1'
#       }
#     }
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -14.6,
#         50.3
#       ]
#     },
#     airTemperature: {
#       value: 10.1,
#       quality: '1'
#     },
#     pressure: {
#       value: 1037.2,
#       quality: '1'
#     },
#     wind: {
#       direction: {
#         angle: 100,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 6.2,
#         quality: '1'
#       }
#     }
#   }
# ]
# ****************************************************************
# 2) Location with section UG1
# [
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -59.7,
#         43.7
#       ]
#     },
#     callLetters: 'VCNP',
#     type: 'FM-13',
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MD1',
#       'MW1',
#       'SA1',
#       'UA1',
#       'UG1'
#     ]
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         173.4,
#         -39.6
#       ]
#     },
#     callLetters: 'SINL',
#     type: 'FM-13',
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MD1',
#       'MW1',
#       'SA1',
#       'UA1',
#       'UG1'
#     ]
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         10.5,
#         67.4
#       ]
#     },
#     callLetters: 'UUQR',
#     type: 'FM-13',
#     sections: [
#       'AG1',
#       'AY1',
#       'GA1',
#       'GF1',
#       'MD1',
#       'MW1',
#       'SA1',
#       'UA1',
#       'UG1'
#     ]
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         4.7,
#         8.1
#       ]
#     },
#     callLetters: 'VCNP',
#     type: 'FM-13',
#     sections: [
#       'AG1',
#       null,
#       'SA1',
#       'UA1',
#       'UG1'
#     ]
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         119.5,
#         -9.1
#       ]
#     },
#     callLetters: 'GUEP',
#     type: 'FM-13',
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MD1',
#       'MW1',
#       'SA1',
#       'UG1'
#     ]
#   }
# ]
# ****************************************************************
# 3) Location with visibility less than 20000 and wind direction angle less than 100
# [
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         127,
#         -28.5
#       ]
#     },
#     airTemperature: {
#       value: 11.7,
#       quality: '1'
#     },
#     wind: {
#       direction: {
#         angle: 10,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 10,
#         quality: '1'
#       }
#     },
#     visibility: {
#       distance: {
#         value: 0,
#         quality: '1'
#       },
#       variability: {
#         value: 'N',
#         quality: '9'
#       }
#     }
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         114,
#         -31.5
#       ]
#     },
#     airTemperature: {
#       value: 22.2,
#       quality: '1'
#     },
#     wind: {
#       direction: {
#         angle: 70,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 7,
#         quality: '1'
#       }
#     },
#     visibility: {
#       distance: {
#         value: 0,
#         quality: '1'
#       },
#       variability: {
#         value: 'N',
#         quality: '9'
#       }
#     }
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -58.3,
#         44.4
#       ]
#     },
#     airTemperature: {
#       value: -1,
#       quality: '1'
#     },
#     wind: {
#       direction: {
#         angle: 70,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 20.6,
#         quality: '1'
#       }
#     },
#     visibility: {
#       distance: {
#         value: 0,
#         quality: '1'
#       },
#       variability: {
#         value: 'N',
#         quality: '9'
#       }
#     }
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         123.5,
#         20.5
#       ]
#     },
#     airTemperature: {
#       value: 10.3,
#       quality: '1'
#     },
#     wind: {
#       direction: {
#         angle: 80,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 4,
#         quality: '1'
#       }
#     },
#     visibility: {
#       distance: {
#         value: 0,
#         quality: '1'
#       },
#       variability: {
#         value: 'N',
#         quality: '9'
#       }
#     }
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         144,
#         42.2
#       ]
#     },
#     airTemperature: {
#       value: -5,
#       quality: '1'
#     },
#     wind: {
#       direction: {
#         angle: 40,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 10,
#         quality: '1'
#       }
#     },
#     visibility: {
#       distance: {
#         value: 100,
#         quality: '1'
#       },
#       variability: {
#         value: 'N',
#         quality: '9'
#       }
#     }
#   }
# ]
# ****************************************************************
# 4) Location with type FM-13 and quaility control process V020
# [
#   {
#     st: 'x+37800-024800',
#     ts: ISODate("1984-03-05T12:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -24.8,
#         37.8
#       ]
#     },
#     callLetters: 'GCCC',
#     qualityControlProcess: 'V020',
#     type: 'FM-13'
#   },
#   {
#     st: 'x+37300+011000',
#     ts: ISODate("1984-03-05T12:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         11,
#         37.3
#       ]
#     },
#     callLetters: 'GYAW',
#     qualityControlProcess: 'V020',
#     type: 'FM-13'
#   },
#   {
#     st: 'x+39500-060000',
#     ts: ISODate("1984-03-05T12:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -60,
#         39.5
#       ]
#     },
#     callLetters: 'GUEQ',
#     qualityControlProcess: 'V020',
#     type: 'FM-13'
#   },
#   {
#     st: 'x+38800+008500',
#     ts: ISODate("1984-03-05T12:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         8.5,
#         38.8
#       ]
#     },
#     callLetters: 'GSEP',
#     qualityControlProcess: 'V020',
#     type: 'FM-13'
#   },
#   {
#     st: 'x+36600+014000',
#     ts: ISODate("1984-03-05T12:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         14,
#         36.6
#       ]
#     },
#     callLetters: '3EGU',
#     qualityControlProcess: 'V020',
#     type: 'FM-13'
#   }
# ]
# ****************************************************************
# 5) Location with a presentWeatherObservationManual element with a condition of 04
# [
#   {
#     ts: ISODate("1984-03-06T12:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -14.1,
#         7.8
#       ]
#     },
#     pastWeatherObservationManual: [
#       {
#         atmosphericCondition: {
#           value: '0',
#           quality: '1'
#         },
#         period: {
#           value: 6,
#           quality: '1'
#         }
#       }
#     ],
#     presentWeatherObservationManual: [
#       {
#         condition: '04',
#         quality: '1'
#       }
#     ]
#   },
#   {
#     ts: ISODate("1984-03-07T18:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -143,
#         45.1
#       ]
#     },
#     pastWeatherObservationManual: [
#       {
#         atmosphericCondition: {
#           value: '0',
#           quality: '1'
#         },
#         period: {
#           value: 6,
#           quality: '1'
#         }
#       }
#     ],
#     presentWeatherObservationManual: [
#       {
#         condition: '04',
#         quality: '1'
#       }
#     ]
#   },
#   {
#     ts: ISODate("1984-03-08T00:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -141.6,
#         45
#       ]
#     },
#     pastWeatherObservationManual: [
#       {
#         atmosphericCondition: {
#           value: '0',
#           quality: '1'
#         },
#         period: {
#           value: 6,
#           quality: '1'
#         }
#       }
#     ],
#     presentWeatherObservationManual: [
#       {
#         condition: '04',
#         quality: '1'
#       }
#     ]
#   },
#   {
#     ts: ISODate("1984-03-08T00:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -45.7,
#         39.2
#       ]
#     },
#     pastWeatherObservationManual: [
#       {
#         atmosphericCondition: {
#           value: '2',
#           quality: '1'
#         },
#         period: {
#           value: 6,
#           quality: '1'
#         }
#       }
#     ],
#     presentWeatherObservationManual: [
#       {
#         condition: '04',
#         quality: '1'
#       }
#     ]
#   },
#   {
#     ts: ISODate("1984-03-08T06:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         73.7,
#         13.3
#       ]
#     },
#     pastWeatherObservationManual: [
#       {
#         atmosphericCondition: {
#           value: '0',
#           quality: '1'
#         },
#         period: {
#           value: 6,
#           quality: '1'
#         }
#       }
#     ],
#     presentWeatherObservationManual: [
#       {
#         condition: '04',
#         quality: '1'
#       }
#     ]
#   }
# ]
# ****************************************************************
# 6) Location with section GF1 or MW1
# [
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -5.3,
#         60.9
#       ]
#     },
#     callLetters: 'TFRB',
#     type: 'FM-13',
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MW1'
#     ]
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -25.2,
#         66.3
#       ]
#     },
#     callLetters: 'TFBY',
#     type: 'FM-13',
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MW1'
#     ]
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -29.7,
#         59.8
#       ]
#     },
#     callLetters: 'TFWB',
#     type: 'FM-13',
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MW1'
#     ]
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -172,
#         79.8
#       ]
#     },
#     callLetters: 'EMIO',
#     type: 'FM-13',
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MA1',
#       'MD1',
#       'MW1'
#     ]
#   },
#   {
#     position: {
#       type: 'Point',
#       coordinates: [
#         -55.9,
#         49.7
#       ]
#     },
#     callLetters: 'SCGB',
#     type: 'FM-13',
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MD1',
#       'MW1'
#     ]
#   }
# ]
# ****************************************************************
# 7) Location with waves that have a height of 1 or a wind speed between 10 and 12 that have a wave measurement
# [
#   {
#     ts: ISODate("1984-03-13T06:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         168.6,
#         40.8
#       ]
#     },
#     wind: {
#       direction: {
#         angle: 290,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 10.3,
#         quality: '1'
#       }
#     },
#     waveMeasurement: {
#       method: 'M',
#       waves: {
#         period: 0,
#         height: 6,
#         quality: '9'
#       },
#       seaState: {
#         code: '99',
#         quality: '9'
#       }
#     }
#   },
#   {
#     ts: ISODate("1984-03-12T06:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         162.5,
#         -14.2
#       ]
#     },
#     wind: {
#       direction: {
#         angle: 130,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 9,
#         quality: '1'
#       }
#     },
#     waveMeasurement: {
#       method: 'M',
#       waves: {
#         period: 0,
#         height: 1,
#         quality: '9'
#       },
#       seaState: {
#         code: '99',
#         quality: '9'
#       }
#     }
#   },
#   {
#     ts: ISODate("1984-03-06T12:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -49.4,
#         43.7
#       ]
#     },
#     wind: {
#       direction: {
#         angle: 270,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 11,
#         quality: '1'
#       }
#     },
#     waveMeasurement: {
#       method: 'I',
#       waves: {
#         period: 0,
#         height: 5,
#         quality: '9'
#       },
#       seaState: {
#         code: '99',
#         quality: '9'
#       }
#     }
#   },
#   {
#     ts: ISODate("1984-03-05T18:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         10.4,
#         59.5
#       ]
#     },
#     wind: {
#       direction: {
#         angle: 330,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 10.3,
#         quality: '1'
#       }
#     },
#     waveMeasurement: {
#       method: 'M',
#       waves: {
#         period: 1,
#         height: 0.5,
#         quality: '9'
#       },
#       seaState: {
#         code: '99',
#         quality: '9'
#       }
#     }
#   },
#   {
#     ts: ISODate("1984-03-05T18:00:00.000Z"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         113,
#         -7.5
#       ]
#     },
#     wind: {
#       direction: {
#         angle: 290,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 6.2,
#         quality: '1'
#       }
#     },
#     waveMeasurement: {
#       method: 'M',
#       waves: {
#         period: 1,
#         height: 1,
#         quality: '9'
#       },
#       seaState: {
#         code: '99',
#         quality: '9'
#       }
#     }
#   }
# ]
# ****************************************************************
# 8)Location with coordinates having latitude equal to -2.1, sorted by longitude
# [
#   {
#     _id: ObjectId("5553a99ae4b02cf71512086e"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -2.1,
#         -28.6
#       ]
#     },
#     type: 'FM-13'
#   },
#   {
#     _id: ObjectId("5553a99ae4b02cf715120ea6"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -2.1,
#         36.6
#       ]
#     },
#     type: 'FM-13'
#   }
# ]
# ****************************************************************
# 9) Locations where visibility distance is between 1 and 999, and wind speed is greater than 10
# [
#   {
#     _id: ObjectId("5553a998e4b02cf715119c13"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -145.5,
#         53.5
#       ]
#     },
#     wind: {
#       direction: {
#         angle: 140,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 10.3,
#         quality: '1'
#       }
#     },
#     visibility: {
#       distance: {
#         value: 500,
#         quality: '1'
#       },
#       variability: {
#         value: 'N',
#         quality: '9'
#       }
#     }
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf7151197e0"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -138.8,
#         69.4
#       ]
#     },
#     wind: {
#       direction: {
#         angle: 290,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 10.3,
#         quality: '1'
#       }
#     },
#     visibility: {
#       distance: {
#         value: 500,
#         quality: '1'
#       },
#       variability: {
#         value: 'N',
#         quality: '9'
#       }
#     }
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511b7d5"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -48.2,
#         46.4
#       ]
#     },
#     wind: {
#       direction: {
#         angle: 220,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 10.3,
#         quality: '1'
#       }
#     },
#     visibility: {
#       distance: {
#         value: 500,
#         quality: '1'
#       },
#       variability: {
#         value: 'N',
#         quality: '9'
#       }
#     }
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf71511a001"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -63.1,
#         46.2
#       ]
#     },
#     wind: {
#       direction: {
#         angle: 140,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 10.3,
#         quality: '1'
#       }
#     },
#     visibility: {
#       distance: {
#         value: 500,
#         quality: '1'
#       },
#       variability: {
#         value: 'N',
#         quality: '9'
#       }
#     }
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf7151197c3"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         -138.8,
#         69.4
#       ]
#     },
#     wind: {
#       direction: {
#         angle: 220,
#         quality: '1'
#       },
#       type: 'N',
#       speed: {
#         rate: 10.3,
#         quality: '1'
#       }
#     },
#     visibility: {
#       distance: {
#         value: 500,
#         quality: '1'
#       },
#       variability: {
#         value: 'N',
#         quality: '9'
#       }
#     }
#   }
# ]
# ****************************************************************
# 10) Locations where sections contain AG1, MD1, OA1, UA1, and SA1, and call letters are PLAT, sorted by their air temperature.
# [
#   {
#     _id: ObjectId("5553a99ae4b02cf715120cc3"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         3.2,
#         51.9
#       ]
#     },
#     callLetters: 'PLAT',
#     airTemperature: {
#       value: 1.4,
#       quality: '1'
#     },
#     sections: [
#       'AG1',
#       'MD1',
#       'OA1',
#       'SA1',
#       'UA1'
#     ]
#   },
#   {
#     _id: ObjectId("5553a99ae4b02cf7151208c6"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         3.2,
#         51.9
#       ]
#     },
#     callLetters: 'PLAT',
#     airTemperature: {
#       value: 1.4,
#       quality: '1'
#     },
#     sections: [
#       'AG1',
#       'MD1',
#       'OA1',
#       'SA1',
#       'UA1'
#     ]
#   },
#   {
#     _id: ObjectId("5553a99ae4b02cf715120567"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         3.6,
#         51.9
#       ]
#     },
#     callLetters: 'PLAT',
#     airTemperature: {
#       value: 1.4,
#       quality: '1'
#     },
#     sections: [
#       'AG1',
#       'MD1',
#       'OA1',
#       'SA1',
#       'UA1'
#     ]
#   },
#   {
#     _id: ObjectId("5553a99ae4b02cf715120b98"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         3.2,
#         51.9
#       ]
#     },
#     callLetters: 'PLAT',
#     airTemperature: {
#       value: 1.5,
#       quality: '1'
#     },
#     sections: [
#       'AG1',
#       'MD1',
#       'OA1',
#       'SA1',
#       'UA1'
#     ]
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511e2bb"),
#     position: {
#       type: 'Point',
#       coordinates: [
#         3.2,
#         51.9
#       ]
#     },
#     callLetters: 'PLAT',
#     airTemperature: {
#       value: 1.6,
#       quality: '1'
#     },
#     sections: [
#       'AG1',
#       'MD1',
#       'OA1',
#       'SA1',
#       'UA1'
#     ]
#   }
# ]

# %% [markdown]
# # BEGIN EXTRA CREDIT WORK

# %%
# !{CONNECT} -f /home/jupyter/snippets/exam1_extra_credit.js
# Out:
#  ****************************************************************
# 1) Document insert with insertOne()
# {
#   acknowledged: true,
#   insertedId: ObjectId("653b274151312edcf71afd69")
# }
# ****************************************************************
# 2) Document insert with insertMany()
# {
#   acknowledged: true,
#   insertedIds: {
#     '0': ObjectId("653b3babfba2de2df27355b2"),
#     '1': ObjectId("653b3babfba2de2df27355b3")
#   }
# }
# ****************************************************************
# 3) Document insert with insertMany()
# {
#   acknowledged: true,
#   insertedIds: {
#     '0': ObjectId("653b3babfba2de2df27355b4"),
#     '1': ObjectId("653b3babfba2de2df27355b5")
#   }
# }
# ****************************************************************
# 4) Document update with updateOne()
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 1,
#   modifiedCount: 1,
#   upsertedCount: 0
# }
# ****************************************************************
# 5) Document update with updateOne() and $push
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 1,
#   modifiedCount: 1,
#   upsertedCount: 0
# }
# ****************************************************************
# 6) Document update with updateMany()
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 59,
#   modifiedCount: 26,
#   upsertedCount: 0
# }
# ****************************************************************
# 7) Document update with updateMany()
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 9967,
#   modifiedCount: 9886,
#   upsertedCount: 0
# }
# ****************************************************************
# 8) Document delete with deleteOne()
# {
#   acknowledged: true,
#   deletedCount: 1
# }
# ****************************************************************
# 9) Document delete with deleteMany()
# {
#   acknowledged: true,
#   deletedCount: 0
# }
# ****************************************************************
# 10) Document delete with deleteMany()
# {
#   acknowledged: true,
#   deletedCount: 0
# }
